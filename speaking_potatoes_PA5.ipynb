# %% [markdown]
# # Programming Assignment 5 - Build your own Conventional Neural Network
#
# After completing this project, you will be able to do the following:
#
# - Build neural network conveniently.
# - Configure with different regularization methods: Dropout, l1 or l2 regulation.
#
# - **574 Only**: Fine tune pre-trained model to build your own projects.
#
# # Dataset
#
# This dataset is provided by our current research project, which utilize 20 kHz acoustic sensing to sense ASL gestures. All the 10 ASL words perform by 5 subjects. All images are generated by using the short-time Fourier transform (STFT) to calculate a spectrogram as the feature representation of the reflected near-ultrasound waves. Based on the Doppler effect, sign language gestures, including both hands and arms, will cause phase and frequency changes of the reflected sonic wave. The spectrogram contains information in both frequency and time domains. The spectrogram is also defined as the Power Spectral Density of the function:
# \begin{equation}
#     \textrm{spectrogram}\{x(t)\}(\tau,\omega)\equiv |X(\tau,\omega)|^{2}= \left| \sum^{\infty}_{n=-\infty}x[n]\omega[n-m]e^{-j\omega n}\right|^{2}
# \end{equation}
# where $x[n]$ is input signal, and $\omega[n-m]$ represents the overlapping Kaiser window function with an adjustable shape factor $\beta$ that improves the resolution and reduces the spectral leakage close to the sidelobes of the signal. The coefficients of the Kaiser window are computed as:
# \begin{equation}
#     \omega[n]=\frac{I_{0}\left(\beta\sqrt{1-\left(\frac{n-N/2}{N/2}\right)^{2}}\right)}{I_{0}(\beta)}, 0 \leq n \leq N
# \end{equation}
#
# This dataset has a training set of 5,000 examples, and a test set of 1,000 examples.
#
# # Submission
#
# 1. **Coding checks (60 points)** - The code for your implementation should be in Python only. The name of the Main file should be main.ipynb or main.py. Please provide necessary comments in the code.
#
# 2. **Written Report (40 points)**: The report should be delivered as a separate pdf file, and it is recommended for you to use the NIPS template to structure your report. You may include comments in the Jupyter Notebook, however you will need to duplicate the results in the report. The report should describe your results, experimental setup and comparison between the results obtained
# from different setting of the algorithm and dataset.**Again, the questions in the Assignment PDF and here are the same (for the written report), we just put them in both places for convenience.**
#
#
# As such, you will submit, one member of your group will subit as a zip file on UBLearns, a ```.zip``` file that contains 3 things:
# - Your completed jupyter notebook.
# - Your written report.

# %%
import numpy as np
## please add the essential libraries
# YOUR CODE HERE
import tensorflow as tf 
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
current_dir = '/content/drive/MyDrive/PA5/pictures/'

# %% [markdown]
# ## Part 1. loading dataset
#
# We have splitted the dataset into training, validation and test. You can load every single folder to load dataset using keras ImageDataGenerator (10 points).

# %%
# load the file from our dataset including training, validation and testing part
img_width, img_height = 224, 224
train_data_dir      = 'pictures/train'
validation_data_dir = 'pictures/val'
test_data_dir       = 'pictures/test'

epochs = 50
batch_size = 16 

# # this is a generator that will read pictures found in
# # subfolers of 'data/train', and indefinitely generate
# # batches of augmented image data
datagen = ImageDataGenerator(rescale=1./255)

# Your Code HERE
train_generator = datagen.flow_from_directory(current_dir+train_data_dir)
valid_generator = datagen.flow_from_directory(current_dir+validation_data_dir)
test_generator  = datagen.flow_from_directory(current_dir+test_data_dir)


# please print the number of samples in each folder 
# Your Code HERE
print('number of samples in train_generator is:',train_generator.n)
print('number of samples in valid_generator is:',valid_generator.n)
print('number of samples in test_generator is:',test_generator.n)
# Out:
# Found 4176 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.
# Found 1392 images belonging to 10 classes.
# number of samples in train_generator is: 4176
# number of samples in valid_generator is: 1392
# number of samples in test_generator is: 1392

# %% [markdown]
# ## Part 2.1 - Build your Neural Network and Train
#
# Build a Convolutional Neural Network with 2 or 3 hidden layers without regularization methods, which includes Conv2D layer, activation Layer. please use training dataset and validation dataset for training processs, and plot the training process with Loss trend and accuracy trend (30 Points).
#
# ## Part 2.2 - Test
#
# Test your machine learning model on the testing set: After finishing all the above steps, fix your hyper-parameters(learning rate, number of neurons per layer) and model parameter and test your model’s performance on the testing set. This shows the effectiveness of your model’s generalization power gained by learning. For test dataset, the performance should be more than 80% (10 Points).

# %%
x_train,y_train = train_generator.next()
#print(x_train.shape)
#print(y_train.shape)
x_val,y_val = valid_generator.next()
#print(x_val.shape)
#print(y_val.shape)
x_test,y_test = test_generator.next()
#print(x_test.shape)
#print(y_test.shape)

# %%
# build conv2D CNN model, be careful with softmax and output layers is 10
# define the input shape of Convolutional Neural Network
# Your Code HERE
# input_shape = (32,256,256,3) #height, width, channel|depth(3==color_img)
# y = (32,10)


# define the Convolutional Neural Network
model = Sequential()
# Your Code HERE
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(256,256,3)))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())

model.add(Dense(units=128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=10,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_120"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_396 (Conv2D)         (None, 254, 254, 32)      896
#
#  dropout_375 (Dropout)       (None, 254, 254, 32)      0
#
#  max_pooling2d_351 (MaxPooli  (None, 127, 127, 32)     0
#  ng2D)
#
#  conv2d_397 (Conv2D)         (None, 125, 125, 64)      18496
#
#  dropout_376 (Dropout)       (None, 125, 125, 64)      0
#
#  max_pooling2d_352 (MaxPooli  (None, 62, 62, 64)       0
#  ng2D)
#
#  conv2d_398 (Conv2D)         (None, 60, 60, 128)       73856
#
#  dropout_377 (Dropout)       (None, 60, 60, 128)       0
#
#  max_pooling2d_353 (MaxPooli  (None, 30, 30, 128)      0
#  ng2D)
#
#  flatten_116 (Flatten)       (None, 115200)            0
#
#  dense_232 (Dense)           (None, 128)               14745728
#
#  dropout_378 (Dropout)       (None, 128)               0
#
#  dense_233 (Dense)           (None, 10)                1290
#
# =================================================================
# Total params: 14,840,266
# Trainable params: 14,840,266
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model and training including the files of compile and fit
#Your code 
#model.compile() = training
epochs=50
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])
#Train the model with training and validation set
#model.fit()
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model_his = model.fit(x_train,y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val),callbacks=[callback])
# Out:
# Epoch 1/50
# 2/2 [==============================] - 2s 1s/step - loss: 15.1054 - accuracy: 0.0938 - val_loss: 3.5236 - val_accuracy: 0.0938
# Epoch 2/50
# 2/2 [==============================] - 0s 122ms/step - loss: 17.6757 - accuracy: 0.1562 - val_loss: 2.3315 - val_accuracy: 0.0938
# Epoch 3/50
# 2/2 [==============================] - 0s 110ms/step - loss: 3.3981 - accuracy: 0.2812 - val_loss: 2.2991 - val_accuracy: 0.1250
# Epoch 4/50
# 2/2 [==============================] - 0s 142ms/step - loss: 2.4154 - accuracy: 0.1562 - val_loss: 2.3055 - val_accuracy: 0.0312
# Epoch 5/50
# 2/2 [==============================] - 0s 108ms/step - loss: 2.0834 - accuracy: 0.2812 - val_loss: 2.2850 - val_accuracy: 0.2812
# Epoch 6/50
# 2/2 [==============================] - 0s 108ms/step - loss: 1.9252 - accuracy: 0.2812 - val_loss: 2.2760 - val_accuracy: 0.1875
# Epoch 7/50
# 2/2 [==============================] - 0s 109ms/step - loss: 1.6265 - accuracy: 0.4062 - val_loss: 2.2662 - val_accuracy: 0.1562
# Epoch 8/50
# 2/2 [==============================] - 0s 140ms/step - loss: 1.3881 - accuracy: 0.5625 - val_loss: 2.2351 - val_accuracy: 0.2812
# Epoch 9/50
# 2/2 [==============================] - 0s 118ms/step - loss: 0.8890 - accuracy: 0.6875 - val_loss: 2.1670 - val_accuracy: 0.3125
# Epoch 10/50
# 2/2 [==============================] - 0s 133ms/step - loss: 0.8919 - accuracy: 0.6562 - val_loss: 2.0876 - val_accuracy: 0.2812
# Epoch 11/50
# 2/2 [==============================] - 0s 113ms/step - loss: 0.6733 - accuracy: 0.6875 - val_loss: 2.0487 - val_accuracy: 0.3125
# Epoch 12/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.2502 - accuracy: 0.9688 - val_loss: 2.0106 - val_accuracy: 0.3438
# Epoch 13/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.6938 - accuracy: 0.8125 - val_loss: 1.9870 - val_accuracy: 0.3750
# Epoch 14/50
# 2/2 [==============================] - 0s 136ms/step - loss: 0.1776 - accuracy: 0.9688 - val_loss: 1.9798 - val_accuracy: 0.2812
# Epoch 15/50
# 2/2 [==============================] - 0s 134ms/step - loss: 0.1681 - accuracy: 0.9375 - val_loss: 1.9889 - val_accuracy: 0.4062
# Epoch 16/50
# 2/2 [==============================] - 0s 134ms/step - loss: 0.1111 - accuracy: 0.9375 - val_loss: 1.9780 - val_accuracy: 0.4062
# Epoch 17/50
# 2/2 [==============================] - 0s 132ms/step - loss: 0.2967 - accuracy: 0.8125 - val_loss: 1.9923 - val_accuracy: 0.2812
# Epoch 18/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1190 - accuracy: 0.9688 - val_loss: 2.0080 - val_accuracy: 0.2812
# Epoch 19/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 2.0387 - val_accuracy: 0.2812
# Epoch 20/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.1858 - accuracy: 0.9375 - val_loss: 2.0711 - val_accuracy: 0.2812
# Epoch 21/50
# 2/2 [==============================] - 0s 107ms/step - loss: 0.1584 - accuracy: 0.9375 - val_loss: 2.0698 - val_accuracy: 0.2812
# Epoch 22/50
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 2.0673 - val_accuracy: 0.2500
# Epoch 23/50
# 2/2 [==============================] - 0s 136ms/step - loss: 0.1214 - accuracy: 0.9062 - val_loss: 2.0513 - val_accuracy: 0.2500
# Epoch 24/50
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0718 - accuracy: 0.9688 - val_loss: 2.0313 - val_accuracy: 0.3750
# Epoch 25/50
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1860 - accuracy: 0.9062 - val_loss: 2.0130 - val_accuracy: 0.4062

# %%
train_loss = model_his.history['loss']
val_loss = model_his.history['val_loss']

epochs = range(len(train_loss))
plt.plot(epochs, train_loss)
plt.plot(epochs, val_loss)
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
train_acc = model_his.history['accuracy']
val_acc = model_his.history['val_accuracy']

epochs = range(len(train_acc))

plt.plot(epochs, train_acc,)
plt.plot(epochs, val_acc)
plt.legend(['Training Acc', 'Test Acc'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %% [markdown]
# %Test

# %%
# Test the model on a testing dataset
# Your Code HERE
loss = model.evaluate(x_test, y_test)
loss
# Out:
# 1/1 [==============================] - 0s 162ms/step - loss: 1.8148 - accuracy: 0.5000
# [1.8147740364074707, 0.5]

# %% [markdown]
# ## Part 2.3 - L1 Regularization. Please add L1 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
# please redefine your model with setting the L1 Regularization in the layer of Conv 2D

# Your code HERE

model1 = Sequential()

model1.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(256,256,3), kernel_regularizer =tf.keras.regularizers.l1(l=0.01)))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu',kernel_regularizer =tf.keras.regularizers.l1(l=0.01)))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu',kernel_regularizer =tf.keras.regularizers.l1(l=0.01)))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Flatten())

model1.add(Dense(units=1280,activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(units=10,activation='softmax'))

# %%
epochs=50
model1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
#Train the model with training and validation set
#model.fit()
model_his = model1.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 330ms/step - loss: 35.6531 - accuracy: 0.0625 - val_loss: 36.0714 - val_accuracy: 0.0938
# Epoch 2/50
# 2/2 [==============================] - 0s 146ms/step - loss: 32.3744 - accuracy: 0.3438 - val_loss: 29.5195 - val_accuracy: 0.2812
# Epoch 3/50
# 2/2 [==============================] - 0s 126ms/step - loss: 28.6302 - accuracy: 0.4375 - val_loss: 28.5057 - val_accuracy: 0.0625
# Epoch 4/50
# 2/2 [==============================] - 0s 125ms/step - loss: 26.7931 - accuracy: 0.5625 - val_loss: 26.9885 - val_accuracy: 0.2812
# Epoch 5/50
# 2/2 [==============================] - 0s 128ms/step - loss: 25.1995 - accuracy: 0.7812 - val_loss: 26.1535 - val_accuracy: 0.3125
# Epoch 6/50
# 2/2 [==============================] - 0s 145ms/step - loss: 23.7491 - accuracy: 0.9062 - val_loss: 25.5887 - val_accuracy: 0.2812
# Epoch 7/50
# 2/2 [==============================] - 0s 125ms/step - loss: 22.4032 - accuracy: 1.0000 - val_loss: 24.8244 - val_accuracy: 0.3125
# Epoch 8/50
# 2/2 [==============================] - 0s 125ms/step - loss: 21.3351 - accuracy: 0.9688 - val_loss: 23.7460 - val_accuracy: 0.2812
# Epoch 9/50
# 2/2 [==============================] - 0s 131ms/step - loss: 20.2169 - accuracy: 1.0000 - val_loss: 23.1084 - val_accuracy: 0.2812
# Epoch 10/50
# 2/2 [==============================] - 0s 151ms/step - loss: 19.2023 - accuracy: 1.0000 - val_loss: 22.5918 - val_accuracy: 0.4062
# Epoch 11/50
# 2/2 [==============================] - 0s 150ms/step - loss: 18.2142 - accuracy: 1.0000 - val_loss: 22.2844 - val_accuracy: 0.3750
# Epoch 12/50
# 2/2 [==============================] - 0s 148ms/step - loss: 17.2690 - accuracy: 1.0000 - val_loss: 21.6573 - val_accuracy: 0.4062
# Epoch 13/50
# 2/2 [==============================] - 0s 123ms/step - loss: 16.3576 - accuracy: 1.0000 - val_loss: 20.9626 - val_accuracy: 0.4062
# Epoch 14/50
# 2/2 [==============================] - 0s 124ms/step - loss: 15.5018 - accuracy: 1.0000 - val_loss: 19.7725 - val_accuracy: 0.4062
# Epoch 15/50
# 2/2 [==============================] - 0s 157ms/step - loss: 14.6394 - accuracy: 1.0000 - val_loss: 18.7467 - val_accuracy: 0.3750
# Epoch 16/50
# 2/2 [==============================] - 0s 146ms/step - loss: 13.9817 - accuracy: 0.9688 - val_loss: 17.6383 - val_accuracy: 0.4375
# Epoch 17/50
# 2/2 [==============================] - 0s 146ms/step - loss: 13.0693 - accuracy: 1.0000 - val_loss: 16.6026 - val_accuracy: 0.4375
# Epoch 18/50
# 2/2 [==============================] - 0s 125ms/step - loss: 12.3416 - accuracy: 1.0000 - val_loss: 15.7341 - val_accuracy: 0.4062
# Epoch 19/50
# 2/2 [==============================] - 0s 123ms/step - loss: 11.6529 - accuracy: 1.0000 - val_loss: 14.9415 - val_accuracy: 0.3750
# Epoch 20/50
# 2/2 [==============================] - 0s 127ms/step - loss: 11.0047 - accuracy: 1.0000 - val_loss: 14.1512 - val_accuracy: 0.3750
# Epoch 21/50
# 2/2 [==============================] - 0s 126ms/step - loss: 10.3861 - accuracy: 1.0000 - val_loss: 13.4211 - val_accuracy: 0.3750
# Epoch 22/50
# 2/2 [==============================] - 0s 146ms/step - loss: 9.8033 - accuracy: 1.0000 - val_loss: 12.7656 - val_accuracy: 0.3750
# Epoch 23/50
# 2/2 [==============================] - 0s 126ms/step - loss: 9.2567 - accuracy: 1.0000 - val_loss: 12.1693 - val_accuracy: 0.3750
# Epoch 24/50
# 2/2 [==============================] - 0s 125ms/step - loss: 8.7514 - accuracy: 1.0000 - val_loss: 11.6611 - val_accuracy: 0.3750
# Epoch 25/50
# 2/2 [==============================] - 0s 127ms/step - loss: 8.2857 - accuracy: 1.0000 - val_loss: 11.2206 - val_accuracy: 0.3750
# Epoch 26/50
# 2/2 [==============================] - 0s 146ms/step - loss: 7.8656 - accuracy: 1.0000 - val_loss: 10.8192 - val_accuracy: 0.4062
# Epoch 27/50
# 2/2 [==============================] - 0s 149ms/step - loss: 7.4874 - accuracy: 1.0000 - val_loss: 10.4564 - val_accuracy: 0.4062
# Epoch 28/50
# 2/2 [==============================] - 0s 146ms/step - loss: 7.1448 - accuracy: 1.0000 - val_loss: 10.1527 - val_accuracy: 0.4375
# Epoch 29/50
# 2/2 [==============================] - 0s 127ms/step - loss: 6.8441 - accuracy: 1.0000 - val_loss: 9.9221 - val_accuracy: 0.4375
# Epoch 30/50
# 2/2 [==============================] - 0s 148ms/step - loss: 6.5869 - accuracy: 1.0000 - val_loss: 9.7365 - val_accuracy: 0.4062
# Epoch 31/50
# 2/2 [==============================] - 0s 126ms/step - loss: 6.3498 - accuracy: 1.0000 - val_loss: 9.5074 - val_accuracy: 0.4062
# Epoch 32/50
# 2/2 [==============================] - 0s 124ms/step - loss: 6.1085 - accuracy: 1.0000 - val_loss: 9.2647 - val_accuracy: 0.4062
# Epoch 33/50
# 2/2 [==============================] - 0s 149ms/step - loss: 5.8722 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.4062
# Epoch 34/50
# 2/2 [==============================] - 0s 148ms/step - loss: 5.6387 - accuracy: 1.0000 - val_loss: 8.6622 - val_accuracy: 0.4062
# Epoch 35/50
# 2/2 [==============================] - 0s 129ms/step - loss: 5.4253 - accuracy: 1.0000 - val_loss: 8.3451 - val_accuracy: 0.4062
# Epoch 36/50
# 2/2 [==============================] - 0s 123ms/step - loss: 5.2170 - accuracy: 1.0000 - val_loss: 8.1332 - val_accuracy: 0.4062
# Epoch 37/50
# 2/2 [==============================] - 0s 128ms/step - loss: 5.0349 - accuracy: 1.0000 - val_loss: 8.0056 - val_accuracy: 0.3750
# Epoch 38/50
# 2/2 [==============================] - 0s 127ms/step - loss: 4.8793 - accuracy: 1.0000 - val_loss: 7.8504 - val_accuracy: 0.4062
# Epoch 39/50
# 2/2 [==============================] - 0s 128ms/step - loss: 4.7286 - accuracy: 1.0000 - val_loss: 7.7364 - val_accuracy: 0.4062
# Epoch 40/50
# 2/2 [==============================] - 0s 126ms/step - loss: 4.5843 - accuracy: 1.0000 - val_loss: 7.6400 - val_accuracy: 0.4375
# Epoch 41/50
# 2/2 [==============================] - 0s 147ms/step - loss: 4.4456 - accuracy: 1.0000 - val_loss: 7.5513 - val_accuracy: 0.4375
# Epoch 42/50
# 2/2 [==============================] - 0s 128ms/step - loss: 4.3279 - accuracy: 1.0000 - val_loss: 7.4498 - val_accuracy: 0.4375
# Epoch 43/50
# 2/2 [==============================] - 0s 128ms/step - loss: 4.2151 - accuracy: 1.0000 - val_loss: 7.2542 - val_accuracy: 0.4375
# Epoch 44/50
# 2/2 [==============================] - 0s 129ms/step - loss: 4.1048 - accuracy: 1.0000 - val_loss: 7.0712 - val_accuracy: 0.4062
# Epoch 45/50
# 2/2 [==============================] - 0s 124ms/step - loss: 3.9990 - accuracy: 1.0000 - val_loss: 6.9225 - val_accuracy: 0.4062
# Epoch 46/50
# 2/2 [==============================] - 0s 128ms/step - loss: 3.8905 - accuracy: 1.0000 - val_loss: 6.8072 - val_accuracy: 0.4375
# Epoch 47/50
# 2/2 [==============================] - 0s 147ms/step - loss: 3.7914 - accuracy: 1.0000 - val_loss: 6.8595 - val_accuracy: 0.4375
# Epoch 48/50
# 2/2 [==============================] - 0s 125ms/step - loss: 3.6878 - accuracy: 1.0000 - val_loss: 6.8968 - val_accuracy: 0.4375
# Epoch 49/50
# 2/2 [==============================] - 0s 149ms/step - loss: 3.5951 - accuracy: 1.0000 - val_loss: 6.9172 - val_accuracy: 0.4062
# Epoch 50/50
# 2/2 [==============================] - 0s 146ms/step - loss: 3.5103 - accuracy: 1.0000 - val_loss: 6.7756 - val_accuracy: 0.4688

# %%
train_loss = model_his.history['loss']
val_loss = model_his.history['val_loss']

epochs = range(len(train_loss))
plt.plot(epochs, train_loss)
plt.plot(epochs, val_loss)
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
train_acc = model_his.history['accuracy']
val_acc = model_his.history['val_accuracy']

epochs = range(len(train_acc))

plt.plot(epochs, train_acc,)
plt.plot(epochs, val_acc)
plt.legend(['Training Acc', 'Test Acc'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %% [markdown]
# ## Part 2.4 - L2 Regularization. Please add L2 regularization setting in your Conv2D layer. Then, train your new model separately, and plot the training process including loss and accuracy. (10 points)

# %%
#please redefine your model and set the L2 Regularization in the layer of Conv 2D
# Your code HERE
model2 = Sequential()

model2.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(256,256,3), kernel_regularizer =tf.keras.regularizers.l2(l=0.01)))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu',kernel_regularizer =tf.keras.regularizers.l2(l=0.01)))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu',kernel_regularizer =tf.keras.regularizers.l2(l=0.01)))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Flatten())

model2.add(Dense(units=300,activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(units=10,activation='softmax'))

# %%
epochs=50
model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
#Train the model with training and validation set
#model.fit()
model_his = model2.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 270ms/step - loss: 5.1048 - accuracy: 0.0625 - val_loss: 4.3645 - val_accuracy: 0.0312
# Epoch 2/50
# 2/2 [==============================] - 0s 110ms/step - loss: 3.5336 - accuracy: 0.2812 - val_loss: 3.5084 - val_accuracy: 0.0625
# Epoch 3/50
# 2/2 [==============================] - 0s 105ms/step - loss: 3.0639 - accuracy: 0.4688 - val_loss: 3.4376 - val_accuracy: 0.0938
# Epoch 4/50
# 2/2 [==============================] - 0s 97ms/step - loss: 2.5646 - accuracy: 0.5312 - val_loss: 3.5885 - val_accuracy: 0.1562
# Epoch 5/50
# 2/2 [==============================] - 0s 121ms/step - loss: 1.9290 - accuracy: 0.8125 - val_loss: 3.4844 - val_accuracy: 0.3438
# Epoch 6/50
# 2/2 [==============================] - 0s 97ms/step - loss: 1.4324 - accuracy: 0.9375 - val_loss: 3.9668 - val_accuracy: 0.3750
# Epoch 7/50
# 2/2 [==============================] - 0s 96ms/step - loss: 1.2438 - accuracy: 0.9375 - val_loss: 5.5640 - val_accuracy: 0.3125
# Epoch 8/50
# 2/2 [==============================] - 0s 97ms/step - loss: 1.1347 - accuracy: 0.9688 - val_loss: 5.6526 - val_accuracy: 0.3438
# Epoch 9/50
# 2/2 [==============================] - 0s 99ms/step - loss: 1.0917 - accuracy: 0.9375 - val_loss: 5.1116 - val_accuracy: 0.4375
# Epoch 10/50
# 2/2 [==============================] - 0s 96ms/step - loss: 1.0213 - accuracy: 0.9375 - val_loss: 5.6968 - val_accuracy: 0.4375
# Epoch 11/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.8615 - accuracy: 1.0000 - val_loss: 6.6084 - val_accuracy: 0.3750
# Epoch 12/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.8320 - accuracy: 1.0000 - val_loss: 7.5800 - val_accuracy: 0.2812
# Epoch 13/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.8698 - accuracy: 0.9688 - val_loss: 7.9849 - val_accuracy: 0.2812
# Epoch 14/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.9021 - accuracy: 0.9375 - val_loss: 6.6979 - val_accuracy: 0.3438
# Epoch 15/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.7531 - accuracy: 1.0000 - val_loss: 6.0150 - val_accuracy: 0.4062
# Epoch 16/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.7283 - accuracy: 1.0000 - val_loss: 5.5903 - val_accuracy: 0.4062
# Epoch 17/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.7067 - accuracy: 1.0000 - val_loss: 5.4039 - val_accuracy: 0.4062
# Epoch 18/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.6811 - accuracy: 1.0000 - val_loss: 5.3336 - val_accuracy: 0.4062
# Epoch 19/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.6603 - accuracy: 1.0000 - val_loss: 5.3354 - val_accuracy: 0.4062
# Epoch 20/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6417 - accuracy: 1.0000 - val_loss: 5.3761 - val_accuracy: 0.4062
# Epoch 21/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.6230 - accuracy: 1.0000 - val_loss: 5.4335 - val_accuracy: 0.4062
# Epoch 22/50
# 2/2 [==============================] - 0s 125ms/step - loss: 0.6061 - accuracy: 1.0000 - val_loss: 5.4712 - val_accuracy: 0.4062
# Epoch 23/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5849 - accuracy: 1.0000 - val_loss: 5.5125 - val_accuracy: 0.4062
# Epoch 24/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5700 - accuracy: 1.0000 - val_loss: 5.5694 - val_accuracy: 0.3750
# Epoch 25/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5590 - accuracy: 1.0000 - val_loss: 5.6555 - val_accuracy: 0.3750
# Epoch 26/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5423 - accuracy: 1.0000 - val_loss: 5.7232 - val_accuracy: 0.3750
# Epoch 27/50
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5280 - accuracy: 1.0000 - val_loss: 5.7712 - val_accuracy: 0.3750
# Epoch 28/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.5158 - accuracy: 1.0000 - val_loss: 5.8056 - val_accuracy: 0.3750
# Epoch 29/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.5034 - accuracy: 1.0000 - val_loss: 5.8265 - val_accuracy: 0.3750
# Epoch 30/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.4928 - accuracy: 1.0000 - val_loss: 5.8386 - val_accuracy: 0.3750
# Epoch 31/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4810 - accuracy: 1.0000 - val_loss: 5.8476 - val_accuracy: 0.3750
# Epoch 32/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4725 - accuracy: 1.0000 - val_loss: 5.8623 - val_accuracy: 0.3750
# Epoch 33/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.4605 - accuracy: 1.0000 - val_loss: 5.8652 - val_accuracy: 0.3750
# Epoch 34/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.4510 - accuracy: 1.0000 - val_loss: 5.8573 - val_accuracy: 0.3750
# Epoch 35/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.4428 - accuracy: 1.0000 - val_loss: 5.8775 - val_accuracy: 0.3750
# Epoch 36/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.4340 - accuracy: 1.0000 - val_loss: 5.8994 - val_accuracy: 0.3750
# Epoch 37/50
# 2/2 [==============================] - 0s 120ms/step - loss: 0.4246 - accuracy: 1.0000 - val_loss: 5.9004 - val_accuracy: 0.3750
# Epoch 38/50
# 2/2 [==============================] - 0s 102ms/step - loss: 0.4166 - accuracy: 1.0000 - val_loss: 5.8918 - val_accuracy: 0.3750
# Epoch 39/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.4091 - accuracy: 1.0000 - val_loss: 5.8928 - val_accuracy: 0.3750
# Epoch 40/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.4011 - accuracy: 1.0000 - val_loss: 5.8970 - val_accuracy: 0.3750
# Epoch 41/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.3974 - accuracy: 1.0000 - val_loss: 5.8447 - val_accuracy: 0.3750
# Epoch 42/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3867 - accuracy: 1.0000 - val_loss: 5.7650 - val_accuracy: 0.3750
# Epoch 43/50
# 2/2 [==============================] - 0s 121ms/step - loss: 0.3799 - accuracy: 1.0000 - val_loss: 5.6960 - val_accuracy: 0.4375
# Epoch 44/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.3734 - accuracy: 1.0000 - val_loss: 5.6399 - val_accuracy: 0.4375
# Epoch 45/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.3670 - accuracy: 1.0000 - val_loss: 5.5832 - val_accuracy: 0.4375
# Epoch 46/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.3632 - accuracy: 1.0000 - val_loss: 5.5487 - val_accuracy: 0.4375
# Epoch 47/50
# 2/2 [==============================] - 0s 122ms/step - loss: 0.3551 - accuracy: 1.0000 - val_loss: 5.5438 - val_accuracy: 0.4375
# Epoch 48/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.3490 - accuracy: 1.0000 - val_loss: 5.5367 - val_accuracy: 0.4375
# Epoch 49/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3435 - accuracy: 1.0000 - val_loss: 5.5275 - val_accuracy: 0.4062
# Epoch 50/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.3379 - accuracy: 1.0000 - val_loss: 5.5258 - val_accuracy: 0.4062

# %%
train_loss = model_his.history['loss']
val_loss = model_his.history['val_loss']

epochs = range(len(train_loss))
plt.plot(epochs, train_loss)
plt.plot(epochs, val_loss)
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
train_acc = model_his.history['accuracy']
val_acc = model_his.history['val_accuracy']

epochs = range(len(train_acc))

plt.plot(epochs, train_acc,)
plt.plot(epochs, val_acc)
plt.legend(['Training Acc', 'Test Acc'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %% [markdown]
# ## Part3 - ** only for 574 students **.
# 1. Fine tune the well pre-trained model, Resnet 50, with different freeze layers.
# First,  load pre-trained resnet 50 from library.
# Second, Fine-tune the model to fit our project, 10-classes.
# Third,  freeze different layers, plot different training process with different frozen layers (at least three different layers).

# %%
# load pre-trained resnet 50 from libarary
# your Code HERE


# Fine-tune the model to fit our project  
# your Code HERE


# define the freeze layers 
# your Code HERE


# Please compile the new model
#model.compile()


#Train the model with training and validation set
#model.fit()
